# %%
import zipfile as zp
import pandas as pd
# from pypac import PACSession as Session #or use requests below if non-ONS
#from requests import Session
from io import BytesIO
import os
import matplotlib.pyplot as plt
# %matplotlib notebook

# %% [markdown]
# ###  Read in files

# %%
# Path to zip files
path = "/Users/lb8075/Loneliness_Data_challenge/Loneliness_notebook/Data/"

# %%
print (path[:-5])
print (path[:-25])
# Out:
# /Users/lb8075/Loneliness_Data_challenge/Loneliness_notebook/
# /Users/lb8075/Loneliness_Data_challenge/

# %%
proc_data = pd.read_csv(path + "final_data.csv")

# %%
proc_data=proc_data.loc[:,['msoa11','insomnia_zscore','alzheimers_zscore','addiction_zscore','depression_zscore']]
proc_data=proc_data.iloc[900:1000]

# %%
insom=proc_data['insomnia_zscore']

# %%
# proc_data['insomnia_zscore'].hist(bins=100,range=(-2,15))
# print (proc_data['insomnia_zscore'].mean())

# %%
proc_data.dtypes
# Out:
# msoa11                object
# insomnia_zscore      float64
# alzheimers_zscore    float64
# addiction_zscore     float64
# depression_zscore    float64
# dtype: object

# %%
pd.plotting.andrews_curves(proc_data,'msoa11')

# %%
insomSeriesz=proc_data['insomnia_zscore']
